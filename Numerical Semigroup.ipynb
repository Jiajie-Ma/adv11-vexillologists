# %%
# load sage packages
load('/Applications/SageMath/NumericalSemigroup.sage')
load('/Applications/SageMath/KunzPoset.sage')
load('/Applications/SageMath/PlotKunzPoset.sage')
from sage.combinat.posets.posets import FinitePoset
# Out:
# true
# Successfully loaded Singular

# %%
S = NumericalSemigroup([6,9,20])

# %%
pres = S.MinimalPresentation()
pres
# Out:
# [[[1, 6, 0], [0, 0, 3]], [[3, 0, 0], [0, 2, 0]]]

# %%
S.PresentationGraph(78)
# Out:
# Graph on 7 vertices

# %%
S.PresentationGraph(78, relations = [[[3, 0, 0], [0, 2, 0]]])
# Out:
# Graph on 7 vertices
