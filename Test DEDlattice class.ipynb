# %%
# load sage packages
load('/sage/NumericalSemigroup.sage')
load('/sage/KunzPoset.sage')
# load('/Applications/SageMath/PlotKunzPoset.sage')
load('DEDlattice.sage')
from sage.combinat.posets.posets import FinitePoset
# Out:
# true
# Successfully loaded Singular

# %%
ded = DEDlattice(6)
child_posets = ded.child_posets(0)
for i in child_posets:
    ded.get_ps()[i].poset.plot()
# Out:
# Graphics object consisting of 12 graphics primitives
